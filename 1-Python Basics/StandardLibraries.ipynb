# %% [markdown]
# Array

# %%
import array

arr= array.array('i', [1,2,3,4])
print(arr)

# %% [markdown]
# Random

# %%
import random as r

print(r.randint(1,10))
# Out:
# 6

# %% [markdown]
# File and Directory Access

# %%
import os
print(os.getcwd())

## make directory

os.mkdir('test_dir')
# Out:
# c:\Users\aksha\OneDrive\Desktop\AI ML Journey\Python\1-Python Basics

# %% [markdown]
# High level operations on files and collection of files

# %%
import shutil

shutil.copyfile('sample.txt','dest.txt')
# Out:
# 'dest.txt'

# %% [markdown]
# Data Serialization

# %%
import json
data= {'name':'Krish', 'age':20}

json_str= json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data= json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Krish", "age": 20}
# <class 'str'>
# {'name': 'Krish', 'age': 20}
# <class 'dict'>

# %% [markdown]
# CSV- Comma Seperated Values

# %%
import csv

with open('example.csv',mode= 'w', newline='') as file:
    writer= csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Krish',30])

with open('example.csv', mode= 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Krish', '30']

# %% [markdown]
# Date Time

# %%
from datetime import datetime, timedelta
now= datetime.now()

print(datetime.now())

yesterday= now- timedelta(days=1)
print(yesterday)
# Out:
# 2026-08-01 20:46:56.356816
# 2026-07-31 20:46:56.356816

# %% [markdown]
# Time

# %%
import time

print(time.time())

time.sleep(2)
print(time.time())
# Out:
# 1785597497.4460769
# 1785597499.4469268

# %% [markdown]
# Regular Expression

# %%
import re
pattern=r'\d+'
text= "There are 123 apples and 445 bananas"

match= re.search(pattern, text)
print(match.group())
# Out:
# 123
