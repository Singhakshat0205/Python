# %%
import pandas as pd

# %%
students= [

    [10,20,30],
    [20,33,34],
    [78,55,85],
    [44,55,78]


]


df= pd.DataFrame(students,columns=['Maths', 'Phy', 'Chem'])
print(df)
print(df.sample())


df.loc[df['Chem']%2==0, 'Chem']=df['Chem']+10
print(df)
# Out:
#    Maths  Phy  Chem
# 0     10   20    30
# 1     20   33    34
# 2     78   55    85
# 3     44   55    78
#    Maths  Phy  Chem
# 2     78   55    85
#    Maths  Phy  Chem
# 0     10   20    40
# 1     20   33    44
# 2     78   55    85
# 3     44   55    88

# %%
##how to change the values of a dataframe
print(df)
df.loc[0,"Maths"]=23

## we can also apply some condition while changing the values
df.loc[df['Phy']>10, 'Phy']=19
print(df)

## below is one more variant of updating the dataframe columns 
df.loc[df['Chem']%2==0, 'Chem']=df['Chem']+10
print(df)

## we can update wither one column or we can pass a list of the columns  we want to update and update all those columns in one go as below:
df.loc[df['Chem']>40, ['Maths', 'Chem', 'Phy']]=5500
print(df)
##changing value of a whole column 

# df['Maths']+=10
print(df)
# Out:
#    Mathematics   Phy  Chem
# 0         5500  5500  5500
# 1         5500  5500  5500
# 2         5500  5500  5500
# 3         5500  5500  5500
#    Mathematics  Phy  Chem  Maths
# 0         5500   19  5500   23.0
# 1         5500   19  5500    NaN
# 2         5500   19  5500    NaN
# 3         5500   19  5500    NaN
#    Mathematics  Phy  Chem  Maths
# 0         5500   19  5510   23.0
# 1         5500   19  5510    NaN
# 2         5500   19  5510    NaN
# 3         5500   19  5510    NaN
#    Mathematics   Phy  Chem   Maths
# 0         5500  5500  5500  5500.0
# 1         5500  5500  5500  5500.0
# 2         5500  5500  5500  5500.0
# 3         5500  5500  5500  5500.0
#    Mathematics   Phy  Chem   Maths
# 0         5500  5500  5500  5500.0
# 1         5500  5500  5500  5500.0
# 2         5500  5500  5500  5500.0
# 3         5500  5500  5500  5500.0

# %%
## we can also rename columns in the data frame
df.rename(
    columns={'Maths':'Mathematics'},
    inplace=True
)


## if we do not use the inplace= true
df= df.rename(
    columns={'Maths':'Mathematics',
    'Chem':'Chemistry',
    'Phy':'Physics'}
)
print(df)
# Out:
#    Mathematics  Physics  Chemistry
# 0           10       20         40
# 1           20       33         44
# 2           78       55         85
# 3           44       55         88

# %%
## Now we will learn how we can add new rows in our data frame

new_row= pd.DataFrame({
    'Mathematics':[99],
    'Physics':[89],
    'Chemistry':[99]
})

new_row.shape

df= pd.concat([df,new_row], ignore_index=True)
print(df)
# Out:
#    Mathematics  Physics  Chemistry
# 0           10       20         40
# 1           20       33         44
# 2           78       55         85
# 3           44       55         88
# 4           99       89         99

# %%
## Now we will learn how we can add new rows in our data frame

print(df)
new_row = pd.DataFrame({
    "name": ["Akshat", 'a','a','aa'],
    "age": [24,12,2,2]
})

df= pd.concat([df, new_row])
print(df)
# Out:
#    Mathematics  Physics  Chemistry
# 0           10       20         40
# 1           20       33         44
# 2           78       55         85
# 3           44       55         88
#    Mathematics  Physics  Chemistry    name   age
# 0         10.0     20.0       40.0     NaN   NaN
# 1         20.0     33.0       44.0     NaN   NaN
# 2         78.0     55.0       85.0     NaN   NaN
# 3         44.0     55.0       88.0     NaN   NaN
# 0          NaN      NaN        NaN  Akshat  24.0
# 1          NaN      NaN        NaN       a  12.0
# 2          NaN      NaN        NaN       a   2.0
# 3          NaN      NaN        NaN      aa   2.0

# %%
df2 = df
print(df2)



df2= df2.rename(
    columns={'Maths':"Mathematics",
    'Phy':'Physics',
    'Chem':'chemistry'})

new_row= pd.DataFrame({
    "Mathematics":[100],
    "chemistry":[99],
    "Physics":[90]
}, )

df2= pd.concat([df2,new_row],ignore_index= True)
print(df2)

# df.loc[df['Chemistry']%2==0, 'Chemistry']=df['Chemistry']+10
# print(df)
# print(df2)

# df2.loc[0, "Mathamatics"]=36
# df2['Physics']+=30
# df2[df2['Physics']>100,'Physics']=98
df2['Physics']+=100
df2.loc[df2['Physics']>100, 'Physics']-=90

subjects = ['Physics', 'Mathematics', 'chemistry']

df2['Total'] = df2[['Mathematics', 'Physics', 'chemistry']].sum(axis=1)

# axis=0 → calculate down the rows → column-wise result
# axis=1 → calculate across columns → row-wise result
## adding more columns to the dataframe


df2['percent_score'] = (df2['Total'] / 300) * 100
print(df2)
##now I want to add rank 
df2['Rank']=df2['Total'].rank(ascending=False)
print(df2)
# Out:
#    Mathematics  Physics  chemistry
# 0           10       20         40
# 1           20       33         44
# 2           78       55         85
# 3           44       55         88
#    Mathematics  Physics  chemistry
# 0           10       20         40
# 1           20       33         44
# 2           78       55         85
# 3           44       55         88
# 4          100       90         99
#    Mathematics  Physics  chemistry  Total  percent_score
# 0           10       30         40     80      26.666667
# 1           20       43         44    107      35.666667
# 2           78       65         85    228      76.000000
# 3           44       65         88    197      65.666667
# 4          100      100         99    299      99.666667
#    Mathematics  Physics  chemistry  Total  percent_score  Rank
# 0           10       30         40     80      26.666667   5.0
# 1           20       43         44    107      35.666667   4.0
# 2           78       65         85    228      76.000000   2.0
# 3           44       65         88    197      65.666667   3.0
# 4          100      100         99    299      99.666667   1.0
