# %%
## getting started with Pandas in Python
import numpy as np
import pandas as pd

# %%
##Panda Series
##1-D arrya holding data of any type

country=['India', 'USA', 'Pakistan']

df= pd.Series(country)
print(df)
# Out:
# 0       India
# 1         USA
# 2    Pakistan
# dtype: object

# %%
marks=[90,29,34,45,66]
subjects=['maths', 'pyhsics','checm', 'bio','hindi']

my_score= pd.Series(marks, index=subjects, name='My_marks')

print(my_score)
print(my_score['maths'])
# Out:
# maths      90
# pyhsics    29
# checm      34
# bio        45
# hindi      66
# Name: My_marks, dtype: int64
# 90

# %%
dic= {
    'maths':90,
    'chem':45
}

marks= pd.Series(dic)
print(marks)
# Out:
# maths    90
# chem     45
# dtype: int64

# %%
marks.is_unique## return true if all the elements are unique
# Out:
# True

# %%
my_score.values
# Out:
# array([90, 29, 34, 45, 66])

# %%
my_score.size
# Out:
# 5

# %%
ind= my_score.index
print(ind)
print(ind[0])
# Out:
# Index(['maths', 'pyhsics', 'checm', 'bio', 'hindi'], dtype='object')
# maths

# %%
df= pd.read_csv('customer_data.csv')

df1=df.squeeze('columns')
print(df1)
dff= pd.read_csv('customer_data.csv', index_col='Age')
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
df.sample()

## give one data row randomly
# Out:
#        CustomerID  Age Gender  Tenure  Usage Frequency  Support Calls  \
# 49567       49568   30   Male      48               30             10
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# 49567             18             Basic          Annual          835
#
#        Last Interaction  Churn
# 49567                11      1

# %%
##value_counts

## frequency count of data

df.value_counts #it gives frequency of each data point for each columns in data
print(df.value_counts)
print(df.value_counts('Gender'))
##gives frequency of each gender
# Out:
# <bound method DataFrame.value_counts of        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
## below will change the original array
df.sort_values('Age', inplace=True)
## below will not make permanent changes in the array
df.sort_values('Age')
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 44228       44229   18  Female       1               25              4
# 27813       27814   18  Female      59               24              6
# 44289       44290   18  Female       3               28              9
# 56919       56920   18  Female      12               27              7
# 40330       40331   18  Female      12               15              8
# ...           ...  ...     ...     ...              ...            ...
# 55560       55561   65    Male      60                4              4
# 24971       24972   65    Male       1               30              4
# 50295       50296   65  Female       1               22              0
# 63499       63500   65    Male      26                1              4
# 61512       61513   65  Female      60               13              6
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
df.head()
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 17057       17058   18    Male      45               21              4
# 49896       49897   18    Male      44               29              5
# 17009       17010   18    Male      34               11              8
# 1472         1473   18  Female      28               21              4
# 23210       23211   18    Male      24               28              0
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# 17057              6             Basic          Annual          943
# 49896             25             Basic          Annual          818
# 17009             11          Standard          Annual          311
# 1472              18             Basic         Monthly          371
# 23210             22          Standard         Monthly          135
#
#        Last Interaction  Churn
# 17057                13      0
# 49896                 8      1
# 17009                21      0
# ...

# %%
df.sort_values('Tenure', ascending=False).head(1).values[0]
# Out:
# array([22817, 26, 'Female', 60, 23, 7, 10, 'Standard', 'Monthly', 452, 27,
#        0], dtype=object)

# %%
dff.sort_index()
##this is going to sort the index column which was given in the data frame dff= pd.read_csv('customer_data.csv', index_col='Age')
# Out:
#      CustomerID  Gender  Tenure  Usage Frequency  Support Calls  \
# Age
# 18        17058    Male      45               21              4
# 18        49897    Male      44               29              5
# 18        17010    Male      34               11              8
# 18         1473  Female      28               21              4
# 18        23211    Male      24               28              0
# ..          ...     ...     ...              ...            ...
# 65          136  Female      26               17             10
# 65        64235  Female      42               14              3
# 65           93  Female       6               21              1
# 65        21661  Female      47               25              3
# 65        21731    Male      44               12              6
#
#      Payment Delay Subscription Type Contract Length  Total Spend  \
# Age
# 18               6             Basic          Annual          943
# ...

# %%
dff.head()
# Out:
#      CustomerID  Gender  Tenure  Usage Frequency  Support Calls  \
# Age
# 22            1  Female      25               14              4
# 41            2  Female      28               28              7
# 47            3    Male      27               10              2
# 35            4    Male       9               12              5
# 53            5  Female      58               24              9
#
#      Payment Delay Subscription Type Contract Length  Total Spend  \
# Age
# 22              27             Basic         Monthly          598
# 41              13          Standard         Monthly          584
# 47              29           Premium          Annual          757
# 35              17           Premium       Quarterly          232
# 53               2          Standard          Annual          533
#
#      Last Interaction  Churn
# Age
# 22                  9      1
# 41                 20      0
# 47                 21      0
# 35                 18      0
# ...

# %%
df2= df['Age']
print(df2)
print(df2.mean())
print(df2.var())
print(df2.sum())
print(df2.product())
print(df2.isnull().sum())
print(df2.value_counts)
print(df.value_counts('Gender'))
print(df.value_counts('Subscription Type'))
print(df.value_counts('Contract Length'))
# Out:
# 0        22
# 1        41
# 2        47
# 3        35
# 4        53
#          ..
# 64369    45
# 64370    37
# 64371    25
# 64372    50
# 64373    52
# Name: Age, Length: 64374, dtype: int64
# 41.97098207350794
# 193.9031549642445
# 2701840
# 0
# 0
# <bound method IndexOpsMixin.value_counts of 0        22
# 1        41
# 2        47
# 3        35
# 4        53
#          ..
# 64369    45
# 64370    37
# 64371    25
# 64372    50
# 64373    52
# Name: Age, Length: 64374, dtype: int64>
# Gender
# Female    34353
# Male      30021
# Name: count, dtype: int64
# Subscription Type
# Standard    21502
# Basic       21451
# Premium     21421
# Name: count, dtype: int64
# Contract Length
# Monthly      22130
# Annual       21410
# Quarterly    20834
# Name: count, dtype: int64

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
df.describe()
##This gives you statistical summary information.
# Out:
#          CustomerID           Age        Tenure  Usage Frequency  \
# count  64374.000000  64374.000000  64374.000000     64374.000000
# mean   32187.500000     41.970982     31.994827        15.080234
# std    18583.317451     13.924911     17.098234         8.816470
# min        1.000000     18.000000      1.000000         1.000000
# 25%    16094.250000     30.000000     18.000000         7.000000
# 50%    32187.500000     42.000000     33.000000        15.000000
# 75%    48280.750000     54.000000     47.000000        23.000000
# max    64374.000000     65.000000     60.000000        30.000000
#
#        Support Calls  Payment Delay   Total Spend  Last Interaction  \
# count   64374.000000   64374.000000  64374.000000      64374.000000
# mean        5.400690      17.133952    541.023379         15.498850
# std         3.114005       8.852211    260.874809          8.638436
# min         0.000000       0.000000    100.000000          1.000000
# ...

# %%
df3= df['Age']

df3.count
#Number of non-missing values.
# Out:
# <bound method Series.count of 0        22
# 1        41
# 2        47
# 3        35
# 4        53
#          ..
# 64369    45
# 64370    37
# 64371    25
# 64372    50
# 64373    52
# Name: Age, Length: 64374, dtype: int64>

# %%
df4= df['Tenure']

print(df4.mean())
print(df4.std())
print(df4.var())
print(df4.min())
print(df4.max())
print(df4.describe())
print(df4.size)
print(df4.shape)

##below Returns the column labels.

print(df.columns)
## we can also convert it into list of columns 
list_of_columns= list(df.columns)
print(list_of_columns)
# Out:
# 31.994827104110357
# 17.098234043436296
# 292.3496074041239
# 1
# 60
# count    64374.000000
# mean        31.994827
# std         17.098234
# min          1.000000
# 25%         18.000000
# 50%         33.000000
# 75%         47.000000
# max         60.000000
# Name: Tenure, dtype: float64
# 64374
# (64374,)
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')
# ['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay', 'Subscription Type', 'Contract Length', 'Total Spend', 'Last Interaction', 'Churn']

# %%
##df.types will give you the data type of each columns
df.dtypes
# Out:
# CustomerID            int64
# Age                   int64
# Gender               object
# Tenure                int64
# Usage Frequency       int64
# Support Calls         int64
# Payment Delay         int64
# Subscription Type    object
# Contract Length      object
# Total Spend           int64
# Last Interaction      int64
# Churn                 int64
# dtype: object

# %%
df.isnull().sum()

## this is going to give the sum of missing values in the data
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64
